# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("cumulative.csv")
df = df.drop(columns=["rowid", "kepid", "kepoi_name", "kepler_name", "koi_pdisposition", "koi_score", "koi_tce_delivname"])
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1       CONFIRMED              0              0              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3  FALSE POSITIVE              0              1              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0    9.488036     2.775000e-05    -2.775000e-05   170.538750
# 1   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 2   19.899140     1.494000e-05    -1.494000e-05   175.850252
# 3    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4    2.525592     3.761000e-06    -3.761000e-06   171.595550
#
#    koi_time0bk_err1     ...      koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# Use train_test_split to create training and testing data
from sklearn.model_selection import train_test_split
y = np.ravel(df['koi_disposition'].values.reshape(-1, 1))
X = df.drop(['koi_disposition'] ,axis=1)
feature_names = X.columns
X.head()
X.drop([])
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0    9.488036
# 1              0              0              0              0   54.418383
# 2              0              1              0              0   19.899140
# 3              0              1              0              0    1.736952
# 4              0              0              0              0    2.525592
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.775000e-05    -2.775000e-05   170.538750          0.002160
# 1     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 2     1.494000e-05    -1.494000e-05   175.850252          0.000581
# 3     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 4     3.761000e-06    -3.761000e-06   171.595550          0.001130
#
#    koi_time0bk_err2     ...      koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)

X_train_scaled = X_minmax.transform(X_train)
X_test_scaled = X_minmax.transform(X_test)
# Out:
# C:\Users\skavy\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %% [markdown]
# # Train the Support Vector Machine

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train_scaled,np.ravel(y_train))
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8502592253735896
# Testing Data Score: 0.838975297346752

# %%
model2 = SVC(kernel='linear')
model2.fit(X_test_scaled,y_test)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the `C` and `gamma` parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [800],
              'gamma': [0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled,y_train)
# Out:
# C:\Users\skavy\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] C=800, gamma=0.01 ...............................................
# [CV] ...... C=800, gamma=0.01, score=0.8948811700182815, total=   2.5s
# [CV] C=800, gamma=0.01 ...............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.7s remaining:    0.0s
# [CV] ...... C=800, gamma=0.01, score=0.8759725400457666, total=   1.6s
# [CV] C=800, gamma=0.01 ...............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.6s remaining:    0.0s
# ...

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 800, 'gamma': 0.01}
# 0.8891430314120159

# %%
#Random First Model
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train_scaled, np.ravel(y_train))
rf.score(X_test_scaled,y_test)
# Out:
# 0.8952424519670631

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr = X.corr()

# plot the heatmap
fig, ax = plt.subplots(figsize=(10,10)) 
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns, ax=ax)

# %%
feature_names =X.columns
important_features = sorted(zip(rf.feature_importances_, feature_names), reverse=True)
feature_names
# Out:
# Index(['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec',
#        'koi_period', 'koi_period_err1', 'koi_period_err2', 'koi_time0bk',
#        'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1',
#        'koi_impact_err2', 'koi_duration', 'koi_duration_err1',
#        'koi_duration_err2', 'koi_depth', 'koi_depth_err1', 'koi_depth_err2',
#        'koi_prad', 'koi_prad_err1', 'koi_prad_err2', 'koi_teq', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
#        'koi_steff', 'koi_steff_err1', 'koi_steff_err2', 'koi_slogg',
#        'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad', 'koi_srad_err1',
#        'koi_srad_err2', 'ra', 'dec', 'koi_kepmag'],
#       dtype='object')

# %%
importantColumns = [x[1] for x in important_features if x[0] >= 0.02]
importantColumns
# Out:
# ['koi_fpflag_co',
#  'koi_fpflag_nt',
#  'koi_fpflag_ss',
#  'koi_model_snr',
#  'koi_prad',
#  'koi_fpflag_ec',
#  'koi_prad_err1',
#  'koi_duration_err2',
#  'koi_steff_err1',
#  'koi_prad_err2',
#  'koi_duration_err1',
#  'koi_steff_err2',
#  'koi_duration',
#  'koi_depth',
#  'koi_time0bk_err2',
#  'koi_period',
#  'koi_time0bk_err1']

# %%
important_features = sorted(zip(rf.feature_importances_, importantColumns), reverse=True)
import matplotlib.pyplot as plt
import seaborn as sns
corr = X.corr()
corr1 = corr.drop(['koi_insol'], axis=1)
# plot the heatmap
fig, ax = plt.subplots(figsize=(10,10)) 
sns.heatmap(corr1, 
        xticklabels=corr1.columns,
        yticklabels=corr1.columns, ax=ax)

# %%
rf2 = RandomForestClassifier(n_estimators=200)
rf2 = rf.fit(X_train_scaled, y_train)
rf2.score(X_test_scaled,y_test)
# Out:
# 0.8934126258005489

# %%
fig, ax = plt.subplots(figsize=(10,10))
dropSelf = np.zeros_like(corr)
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns, ax=ax)

# %%
rf3 = RandomForestClassifier(n_estimators=200)
rf3 = rf.fit(X_train_scaled, y_train)
rf3.score(X_test_scaled,y_test)
# Out:
# 0.8947849954254345
